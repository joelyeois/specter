# %%
from pdbtools import fetch_pdb_file
# %load_ext autoreload
# %autoreload 2

# %%
fetch_pdb_file('5mac')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fetch_pdb_file('5mac')
#
# File ~/czii/cryosim/pdbtools.py:29, in fetch_pdb_file(pdbcode, output, force, assembly)
#      27 url = "https://files.rcsb.org/download/{code}.pdb{assembly}.gz".format(code=pdbcode, assembly="1" if assembly else "")
#      28 filename = Path(output) / "{}.pdb".format(pdbcode)  #"".join([output,'/',pdbcode, '.pdb'])
# ---> 29 if (os.path.isfile(filename)) and not force:
#      30     return filename
#      31 try:
#
# NameError: name 'os' is not defined
