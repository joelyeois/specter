# %%
import matplotlib.pyplot as plt
from cryosim.detectors import k3_300kv, perfect_detector, falcon4i_300kv

# %load_ext autoreload
# %autoreload 2

# %%
k_f, falcon4i = falcon4i_300kv(256, 1, return1d=True)
k, k3 = k3_300kv(256, 1, return1d=True)
k_p, perfect = perfect_detector(256, 1, return1d=True)
k_p, perfect = perfect_detector(256, 1, return1d=True)
plt.plot(k_f, falcon4i)
plt.plot(k, k3, ls="--")
plt.plot(k_p, perfect)
plt.ylim([0, 1])
plt.xlabel("k (1/A)")
plt.ylabel("MTF")
# plt.imshow(mtf, vmin=0, vmax=1, cmap='bone')
# plt.colorbar()
# Out:
# Text(0, 0.5, 'MTF')
