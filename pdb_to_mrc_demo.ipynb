# %%
from pdb_to_mrc import PDBtoMRC
from plotting_tools import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Instantiate class

# %%
pdb_code = '5mac'
pdb2mrc = PDBtoMRC(pdb_code)

# %% [markdown]
# ## Download PDB file

# %%
pdb2mrc.fetch_pdb()
# Out:
# PDB file saved to: ./pda-data/5mac.cif

# %% [markdown]
# ## Compute particle potential

# %%
pdb2mrc.build_particle(n=256, dx=1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:02<00:00,  2.56it/s]

# %%
plot3d(pdb2mrc.particle)

# %% [markdown]
# ## Solvate

# %%
pdb2mrc.solvate()
# Out:
#   0%|                                                                                                                                                                               | 0/5 [00:00<?, ?it/s]

# %%
plot3d(pdb2mrc.particle)

# %%
plot3d(ice_vol_3d + vol_3d)

# %%
plot3d(ice_vol_3d)

# %%
plot3d(vol_3d)
